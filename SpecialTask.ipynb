# %% [markdown]
# <a href="https://colab.research.google.com/github/Janhavi4230/Special-Task/blob/main/SpecialTask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-71f369cd-59cb-4da3-81c6-b0a5e32c93bd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-71f369cd-59cb-4da3-81c6-b0a5e32c93bd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filepath='/content/Chocolate_Sales.csv'
df=pd.read_csv(filepath)

# %%
df.head()
# Out:
#      Order_ID            Product    Country Channel    Salesperson  \
# 0  ORD-069833   Truffle Gift Box  Australia  Retail    Arjun Mehta
# 1  ORD-090726       85% Dark Bar  Australia  Retail    Arjun Mehta
# 2  ORD-042159       70% Dark Bar      Japan  Retail  Hannah Müller
# 3  ORD-197166  Hazelnut Milk Bar    Germany  Retail    Arjun Mehta
# 4  ORD-112162  Almond Crunch Bar  Australia  Retail      Yuki Sato
#
#    Order_Date  Discount_Pct  Price_per_Box  Marketing_Spend  Boxes_Shipped  \
# 0  2022-12-11           3.5          13.72           202.03             71
# 1  2023-03-14           9.4           3.30            55.18             84
# 2  2023-12-21           4.9          18.21            60.65             35
# 3  2023-12-18          15.0           2.66            52.00             92
# 4  2023-08-18           4.4           2.75           187.44            214
#
#    Amount
# 0  912.31
# 1  245.91
# 2   583.7
# 3  211.27
# 4  549.69

# %%
df.tail()
# Out:
#           Order_ID             Product    Country    Channel    Salesperson  \
# 199995  ORD-053460        70% Dark Bar  Australia     Retail  Beatriz Souza
# 199996  ORD-010743    Truffle Gift Box      India  Wholesale    Arjun Mehta
# 199997  ORD-049690  Salted Caramel Bar      Japan     Online    Arjun Mehta
# 199998  ORD-189637        85% Dark Bar      Japan  Wholesale    Rohan Patel
# 199999  ORD-061616       Mint Dark Bar  Australia     Retail  Hannah Müller
#
#         Order_Date  Discount_Pct  Price_per_Box  Marketing_Spend  \
# 199995  2022-05-27          10.6           3.39           186.19
# 199996  2022-09-06          17.3           3.07            42.28
# 199997  2022-06-16          18.3           2.74           100.19
# 199998  2022-10-14           9.3          14.30            29.96
# 199999  2022-01-25           7.2           3.01           270.86
#
#         Boxes_Shipped  Amount
# 199995            125  418.56
# 199996            148  366.47
# ...

# %%
df.shape
# Out:
# (200000, 11)

# %%
df.columns
# Out:
# Index(['Order_ID', 'Product', 'Country', 'Channel', 'Salesperson',
#        'Order_Date', 'Discount_Pct', 'Price_per_Box', 'Marketing_Spend',
#        'Boxes_Shipped', 'Amount'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Order_ID         200000 non-null  object
#  1   Product          200000 non-null  object
#  2   Country          200000 non-null  object
#  3   Channel          200000 non-null  object
#  4   Salesperson      200000 non-null  object
#  5   Order_Date       199563 non-null  object
#  6   Discount_Pct     199511 non-null  float64
#  7   Price_per_Box    199543 non-null  float64
#  8   Marketing_Spend  199539 non-null  float64
#  9   Boxes_Shipped    200000 non-null  int64
#  10  Amount           200000 non-null  object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 16.8+ MB

# %%
df.describe()
# Out:
#         Discount_Pct  Price_per_Box  Marketing_Spend  Boxes_Shipped
# count  199511.000000  199543.000000    199539.000000  200000.000000
# mean       13.107457       5.911507        95.450141     139.584105
# std         6.374477       4.954976        66.243760     118.665393
# min         0.000000       2.040000         4.300000   -1642.000000
# 25%         8.300000       2.950000        52.270000      67.000000
# 50%        12.600000       3.280000        78.850000     113.000000
# 75%        17.500000       4.570000       118.710000     180.000000
# max        38.300000      21.650000       798.222443    3811.000000

# %%
df.dtypes
# Out:
# Order_ID            object
# Product             object
# Country             object
# Channel             object
# Salesperson         object
# Order_Date          object
# Discount_Pct       float64
# Price_per_Box      float64
# Marketing_Spend    float64
# Boxes_Shipped        int64
# Amount              object
# dtype: object

# %%
df.isnull()
# Out:
#         Order_ID  Product  Country  Channel  Salesperson  Order_Date  \
# 0          False    False    False    False        False       False
# 1          False    False    False    False        False       False
# 2          False    False    False    False        False       False
# 3          False    False    False    False        False       False
# 4          False    False    False    False        False       False
# ...          ...      ...      ...      ...          ...         ...
# 199995     False    False    False    False        False       False
# 199996     False    False    False    False        False       False
# 199997     False    False    False    False        False       False
# 199998     False    False    False    False        False       False
# 199999     False    False    False    False        False       False
#
#         Discount_Pct  Price_per_Box  Marketing_Spend  Boxes_Shipped  Amount
# ...

# %%
df.sum
# Out:
# <bound method DataFrame.sum of           Order_ID             Product    Country    Channel    Salesperson  \
# 0       ORD-069833    Truffle Gift Box  Australia     Retail    Arjun Mehta
# 1       ORD-090726        85% Dark Bar  Australia     Retail    Arjun Mehta
# 2       ORD-042159        70% Dark Bar      Japan     Retail  Hannah Müller
# 3       ORD-197166   Hazelnut Milk Bar    Germany     Retail    Arjun Mehta
# 4       ORD-112162   Almond Crunch Bar  Australia     Retail      Yuki Sato
# ...            ...                 ...        ...        ...            ...
# 199995  ORD-053460        70% Dark Bar  Australia     Retail  Beatriz Souza
# 199996  ORD-010743    Truffle Gift Box      India  Wholesale    Arjun Mehta
# 199997  ORD-049690  Salted Caramel Bar      Japan     Online    Arjun Mehta
# 199998  ORD-189637        85% Dark Bar      Japan  Wholesale    Rohan Patel
# 199999  ORD-061616       Mint Dark Bar  Australia     Retail  Hannah Müller
#
# ...

# %%
df.nunique()
# Out:
# Order_ID           200000
# Product                12
# Country                 5
# Channel                 3
# Salesperson            25
# Order_Date           2000
# Discount_Pct         2517
# Price_per_Box        1381
# Marketing_Spend     27319
# Boxes_Shipped        1521
# Amount              85605
# dtype: int64

# %%
df.sample(5)
# Out:
#          Order_ID               Product    Country    Channel     Salesperson  \
# 64636  ORD-022238          70% Dark Bar  Australia     Retail     Arjun Mehta
# 80172  ORD-065049          70% Dark Bar  Australia     Retail     Arjun Mehta
# 68325  ORD-047811      Milk Classic Bar     Brazil     Retail  Isabella Rossi
# 32979  ORD-044205     Almond Crunch Bar     Brazil     Retail     Arjun Mehta
# 69442  ORD-055731  Mixed Assortment Box     Brazil  Wholesale     Arjun Mehta
#
#        Order_Date  Discount_Pct  Price_per_Box  Marketing_Spend  \
# 64636  2022-06-07          12.1           3.07            74.16
# 80172  2022-12-03           8.3           4.53              NaN
# 68325  2023-11-02           6.9           2.69            57.07
# 32979  2022-12-12           8.9           2.95            80.37
# 69442  2023-03-04           6.6           3.10            78.25
#
#        Boxes_Shipped   Amount
# 64636             98   267.56
# 80172             89   369.51
# ...

# %%
df.min
# Out:
# <bound method DataFrame.min of           Order_ID             Product    Country    Channel    Salesperson  \
# 0       ORD-069833    Truffle Gift Box  Australia     Retail    Arjun Mehta
# 1       ORD-090726        85% Dark Bar  Australia     Retail    Arjun Mehta
# 2       ORD-042159        70% Dark Bar      Japan     Retail  Hannah Müller
# 3       ORD-197166   Hazelnut Milk Bar    Germany     Retail    Arjun Mehta
# 4       ORD-112162   Almond Crunch Bar  Australia     Retail      Yuki Sato
# ...            ...                 ...        ...        ...            ...
# 199995  ORD-053460        70% Dark Bar  Australia     Retail  Beatriz Souza
# 199996  ORD-010743    Truffle Gift Box      India  Wholesale    Arjun Mehta
# 199997  ORD-049690  Salted Caramel Bar      Japan     Online    Arjun Mehta
# 199998  ORD-189637        85% Dark Bar      Japan  Wholesale    Rohan Patel
# 199999  ORD-061616       Mint Dark Bar  Australia     Retail  Hannah Müller
#
# ...

# %%
df.value_counts()
# Out:
# Order_ID    Product               Country    Channel    Salesperson      Order_Date  Discount_Pct  Price_per_Box  Marketing_Spend  Boxes_Shipped  Amount
# ORD-200000  70% Dark Bar          Australia  Retail     Arjun Mehta      2022-12-24  19.80         3.32           49.53             100           261.56     1
# ORD-000001  White Choco Bar       Brazil     Wholesale  Sora Watanabe    2023-12-17  6.80          13.16          76.03             99            1235.23    1
# ORD-000002  Mixed Assortment Box  Germany    Wholesale  Yuki Sato        2022-03-02  1.70          2.82           43.14             190           523.46     1
# ORD-000003  Milk Classic Bar      Australia  Retail     Rafael Oliveira  2023-05-11  3.40          2.37           53.83             80            170.85     1
# ORD-000004  Pralines Gift Box     Australia  Retail     Priya Sharma     2023-05-05  7.30          3.37           127.85            92            300.95     1
# ...

# %%
df.max
# Out:
# <bound method DataFrame.max of           Order_ID             Product    Country    Channel    Salesperson  \
# 0       ORD-069833    Truffle Gift Box  Australia     Retail    Arjun Mehta
# 1       ORD-090726        85% Dark Bar  Australia     Retail    Arjun Mehta
# 2       ORD-042159        70% Dark Bar      Japan     Retail  Hannah Müller
# 3       ORD-197166   Hazelnut Milk Bar    Germany     Retail    Arjun Mehta
# 4       ORD-112162   Almond Crunch Bar  Australia     Retail      Yuki Sato
# ...            ...                 ...        ...        ...            ...
# 199995  ORD-053460        70% Dark Bar  Australia     Retail  Beatriz Souza
# 199996  ORD-010743    Truffle Gift Box      India  Wholesale    Arjun Mehta
# 199997  ORD-049690  Salted Caramel Bar      Japan     Online    Arjun Mehta
# 199998  ORD-189637        85% Dark Bar      Japan  Wholesale    Rohan Patel
# 199999  ORD-061616       Mint Dark Bar  Australia     Retail  Hannah Müller
#
# ...

# %%
df.mean
# Out:
# <bound method DataFrame.mean of           Order_ID             Product    Country    Channel    Salesperson  \
# 0       ORD-069833    Truffle Gift Box  Australia     Retail    Arjun Mehta
# 1       ORD-090726        85% Dark Bar  Australia     Retail    Arjun Mehta
# 2       ORD-042159        70% Dark Bar      Japan     Retail  Hannah Müller
# 3       ORD-197166   Hazelnut Milk Bar    Germany     Retail    Arjun Mehta
# 4       ORD-112162   Almond Crunch Bar  Australia     Retail      Yuki Sato
# ...            ...                 ...        ...        ...            ...
# 199995  ORD-053460        70% Dark Bar  Australia     Retail  Beatriz Souza
# 199996  ORD-010743    Truffle Gift Box      India  Wholesale    Arjun Mehta
# 199997  ORD-049690  Salted Caramel Bar      Japan     Online    Arjun Mehta
# 199998  ORD-189637        85% Dark Bar      Japan  Wholesale    Rohan Patel
# 199999  ORD-061616       Mint Dark Bar  Australia     Retail  Hannah Müller
#
# ...
